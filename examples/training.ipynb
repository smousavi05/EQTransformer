# %% [markdown]
# # (IV) Model Building
# You can also train the neural network on your data and build and test your own model using the following modules.

# %% [markdown]
# ### 1) Training:

# %% [markdown]
# You can build your own EQTransformer with varying encoder sizes and train it using your own data. Your data should be in the same format as our sample data.

# %%
from EQTransformer.core.trainer import trainer
trainer(input_hdf5='../ModelsAndSampleData/100samples.hdf5',
        input_csv='../ModelsAndSampleData/100samples.csv',
        output_name='test_trainer',                
        cnn_blocks=2,
        lstm_blocks=1,
        padding='same',
        activation='relu',
        drop_rate=0.2,
        label_type='gaussian',
        add_event_r=0.6,
        add_gap_r=0.2,
        shift_event_r=0.9,
        add_noise_r=0.5, 
        mode='generator',
        train_valid_test_split=[0.60, 0.20, 0.20],
        batch_size=20,
        epochs=10, 
        patience=2,
        gpuid=None,
        gpu_limit=None)
# Out:
# Using TensorFlow backend.
# /Users/mostafamousavi/anaconda3/envs/eqtdemo/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/mostafamousavi/anaconda3/envs/eqtdemo/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/mostafamousavi/anaconda3/envs/eqtdemo/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/mostafamousavi/anaconda3/envs/eqtdemo/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/mostafamousavi/anaconda3/envs/eqtdemo/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/mostafamousavi/anaconda3/envs/eqtdemo/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/mostafamousavi/anaconda3/envs/eqtdemo/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/mostafamousavi/anaconda3/envs/eqtdemo/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/mostafamousavi/anaconda3/envs/eqtdemo/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/mostafamousavi/anaconda3/envs/eqtdemo/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/mostafamousavi/anaconda3/envs/eqtdemo/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/mostafamousavi/anaconda3/envs/eqtdemo/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From /Users/mostafamousavi/anaconda3/envs/eqtdemo/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Learning rate:  0.001
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 6000, 3)      0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 6000, 8)      272         input[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 3000, 8)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 3000, 16)     1168        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 1500, 16)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 1500, 16)     1808        max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 750, 16)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 750, 32)      3616        max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 375, 32)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 375, 32)      5152        max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 188, 32)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 188, 64)      10304       max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 94, 64)       0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 94, 64)       12352       max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 47, 64)       0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 47, 64)       256         max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 47, 64)       0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_1 (SpatialDro (None, 47, 64)       0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 47, 64)       12352       spatial_dropout1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 47, 64)       256         conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 47, 64)       0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_2 (SpatialDro (None, 47, 64)       0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 47, 64)       12352       spatial_dropout1d_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 47, 64)       0           max_pooling1d_7[0][0]
#                                                                  conv1d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 47, 64)       256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 47, 64)       0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_3 (SpatialDro (None, 47, 64)       0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 47, 64)       12352       spatial_dropout1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 47, 64)       256         conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 47, 64)       0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_4 (SpatialDro (None, 47, 64)       0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 47, 64)       12352       spatial_dropout1d_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 47, 64)       0           add_1[0][0]
#                                                                  conv1d_11[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 47, 32)       10368       add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 47, 16)       528         bidirectional_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 47, 16)       64          conv1d_12[0][0]
# __________________________________________________________________________________________________
# attentionD0 (SeqSelfAttention)  [(None, 47, 16), (No 1089        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 47, 16)       0           batch_normalization_5[0][0]
#                                                                  attentionD0[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 47, 16)       32          add_3[0][0]
# __________________________________________________________________________________________________
# feed_forward_1 (FeedForward)    (None, 47, 16)       4240        layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 47, 16)       0           layer_normalization_1[0][0]
#                                                                  feed_forward_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 47, 16)       32          add_4[0][0]
# __________________________________________________________________________________________________
# attentionD (SeqSelfAttention)   [(None, 47, 16), (No 1089        layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 47, 16)       0           layer_normalization_2[0][0]
#                                                                  attentionD[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 47, 16)       32          add_5[0][0]
# __________________________________________________________________________________________________
# feed_forward_2 (FeedForward)    (None, 47, 16)       4240        layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 47, 16)       0           layer_normalization_3[0][0]
#                                                                  feed_forward_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 47, 16)       32          add_6[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 47, 16)       2112        layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 47, 16)       2112        layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# attentionP (SeqSelfAttention)   [(None, 47, 16), (No 1089        lstm_2[0][0]
# __________________________________________________________________________________________________
# attentionS (SeqSelfAttention)   [(None, 47, 16), (No 1089        lstm_3[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_1 (UpSampling1D)  (None, 94, 16)       0           layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_8 (UpSampling1D)  (None, 94, 16)       0           attentionP[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_15 (UpSampling1D) (None, 94, 16)       0           attentionS[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 94, 64)       3136        up_sampling1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 94, 64)       3136        up_sampling1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 94, 64)       3136        up_sampling1d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_2 (UpSampling1D)  (None, 188, 64)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_9 (UpSampling1D)  (None, 188, 64)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_16 (UpSampling1D) (None, 188, 64)      0           conv1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 188, 64)      20544       up_sampling1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 188, 64)      20544       up_sampling1d_9[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 188, 64)      20544       up_sampling1d_16[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_3 (UpSampling1D)  (None, 376, 64)      0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_10 (UpSampling1D) (None, 376, 64)      0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_17 (UpSampling1D) (None, 376, 64)      0           conv1d_28[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 376, 32)      10272       up_sampling1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 376, 32)      10272       up_sampling1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 376, 32)      10272       up_sampling1d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_4 (UpSampling1D)  (None, 752, 32)      0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_11 (UpSampling1D) (None, 752, 32)      0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_18 (UpSampling1D) (None, 752, 32)      0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# cropping1d_1 (Cropping1D)       (None, 750, 32)      0           up_sampling1d_4[0][0]
# __________________________________________________________________________________________________
# cropping1d_2 (Cropping1D)       (None, 750, 32)      0           up_sampling1d_11[0][0]
# __________________________________________________________________________________________________
# cropping1d_3 (Cropping1D)       (None, 750, 32)      0           up_sampling1d_18[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 750, 32)      7200        cropping1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 750, 32)      7200        cropping1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 750, 32)      7200        cropping1d_3[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_5 (UpSampling1D)  (None, 1500, 32)     0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_12 (UpSampling1D) (None, 1500, 32)     0           conv1d_23[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_19 (UpSampling1D) (None, 1500, 32)     0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 1500, 16)     3600        up_sampling1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 1500, 16)     3600        up_sampling1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 1500, 16)     3600        up_sampling1d_19[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_6 (UpSampling1D)  (None, 3000, 16)     0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_13 (UpSampling1D) (None, 3000, 16)     0           conv1d_24[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_20 (UpSampling1D) (None, 3000, 16)     0           conv1d_31[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 3000, 16)     2320        up_sampling1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 3000, 16)     2320        up_sampling1d_13[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 3000, 16)     2320        up_sampling1d_20[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_7 (UpSampling1D)  (None, 6000, 16)     0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_14 (UpSampling1D) (None, 6000, 16)     0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_21 (UpSampling1D) (None, 6000, 16)     0           conv1d_32[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 6000, 8)      1416        up_sampling1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 6000, 8)      1416        up_sampling1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 6000, 8)      1416        up_sampling1d_21[0][0]
# __________________________________________________________________________________________________
# detector (Conv1D)               (None, 6000, 1)      89          conv1d_19[0][0]
# __________________________________________________________________________________________________
# picker_P (Conv1D)               (None, 6000, 1)      89          conv1d_26[0][0]
# __________________________________________________________________________________________________
# picker_S (Conv1D)               (None, 6000, 1)      89          conv1d_33[0][0]
# ==================================================================================================
# Total params: 258,983
# Trainable params: 258,439
# Non-trainable params: 544
# __________________________________________________________________________________________________
# Started training in generator mode ...
# WARNING:tensorflow:From /Users/mostafamousavi/anaconda3/envs/eqtdemo/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/10
# Learning rate:  0.001
# 6/6 [==============================] - 19s 3s/step - loss: 0.6174 - detector_loss: 0.5629 - picker_P_loss: 0.6692 - picker_S_loss: 0.5830 - detector_f1: 0.0218 - picker_P_f1: 1.2918e-04 - picker_S_f1: 7.4680e-05 - val_loss: 0.4382 - val_detector_loss: 0.5591 - val_picker_P_loss: 0.5808 - val_picker_S_loss: 0.3216 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 0.43825, saving model to /Users/mostafamousavi/Desktop/EQTransformer/examples/test_trainer_outputs/models/test_trainer_001.h5
# Epoch 2/10
# Learning rate:  0.001
# 6/6 [==============================] - 4s 658ms/step - loss: 0.2182 - detector_loss: 0.5283 - picker_P_loss: 0.3417 - picker_S_loss: 0.0982 - detector_f1: 0.0000e+00 - picker_P_f1: 0.0000e+00 - picker_S_f1: 0.0000e+00 - val_loss: 0.0785 - val_detector_loss: 0.5190 - val_picker_P_loss: 0.0307 - val_picker_S_loss: 0.0711 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00002: val_loss improved from 0.43825 to 0.07855, saving model to /Users/mostafamousavi/Desktop/EQTransformer/examples/test_trainer_outputs/models/test_trainer_002.h5
# Epoch 3/10
# Learning rate:  0.001
# 6/6 [==============================] - 4s 739ms/step - loss: 0.1084 - detector_loss: 0.5401 - picker_P_loss: 0.0659 - picker_S_loss: 0.0978 - detector_f1: 0.0000e+00 - picker_P_f1: 0.0000e+00 - picker_S_f1: 0.0000e+00 - val_loss: 0.1043 - val_detector_loss: 0.4932 - val_picker_P_loss: 0.0839 - val_picker_S_loss: 0.0813 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00003: val_loss did not improve from 0.07855
# Epoch 4/10
# Learning rate:  0.001
# 6/6 [==============================] - 4s 708ms/step - loss: 0.1073 - detector_loss: 0.5063 - picker_P_loss: 0.1037 - picker_S_loss: 0.0712 - detector_f1: 0.0000e+00 - picker_P_f1: 0.0000e+00 - picker_S_f1: 0.0000e+00 - val_loss: 0.0686 - val_detector_loss: 0.4793 - val_picker_P_loss: 0.0598 - val_picker_S_loss: 0.0352 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00004: val_loss improved from 0.07855 to 0.06859, saving model to /Users/mostafamousavi/Desktop/EQTransformer/examples/test_trainer_outputs/models/test_trainer_004.h5
# Epoch 5/10
# Learning rate:  0.001
# 6/6 [==============================] - 4s 698ms/step - loss: 0.0693 - detector_loss: 0.4903 - picker_P_loss: 0.0569 - picker_S_loss: 0.0377 - detector_f1: 0.0000e+00 - picker_P_f1: 0.0000e+00 - picker_S_f1: 0.0000e+00 - val_loss: 0.0603 - val_detector_loss: 0.4743 - val_picker_P_loss: 0.0280 - val_picker_S_loss: 0.0437 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00005: val_loss improved from 0.06859 to 0.06026, saving model to /Users/mostafamousavi/Desktop/EQTransformer/examples/test_trainer_outputs/models/test_trainer_005.h5
# Epoch 6/10
# Learning rate:  0.001
# 6/6 [==============================] - 4s 663ms/step - loss: 0.0621 - detector_loss: 0.4715 - picker_P_loss: 0.0364 - picker_S_loss: 0.0412 - detector_f1: 0.0000e+00 - picker_P_f1: 0.0000e+00 - picker_S_f1: 0.0000e+00 - val_loss: 0.0670 - val_detector_loss: 0.4924 - val_picker_P_loss: 0.0483 - val_picker_S_loss: 0.0395 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00006: val_loss did not improve from 0.06026
# Epoch 7/10
# Learning rate:  0.001
# 6/6 [==============================] - 4s 658ms/step - loss: 0.0590 - detector_loss: 0.4639 - picker_P_loss: 0.0393 - picker_S_loss: 0.0342 - detector_f1: 0.0000e+00 - picker_P_f1: 0.0000e+00 - picker_S_f1: 0.0000e+00 - val_loss: 0.0515 - val_detector_loss: 0.4496 - val_picker_P_loss: 0.0318 - val_picker_S_loss: 0.0273 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00007: val_loss improved from 0.06026 to 0.05150, saving model to /Users/mostafamousavi/Desktop/EQTransformer/examples/test_trainer_outputs/models/test_trainer_007.h5
# Epoch 8/10
# Learning rate:  0.001
# 6/6 [==============================] - 4s 689ms/step - loss: 0.0503 - detector_loss: 0.3852 - picker_P_loss: 0.0313 - picker_S_loss: 0.0313 - detector_f1: 0.0000e+00 - picker_P_f1: 0.0000e+00 - picker_S_f1: 0.0000e+00 - val_loss: 0.0496 - val_detector_loss: 0.4606 - val_picker_P_loss: 0.0266 - val_picker_S_loss: 0.0265 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00008: val_loss improved from 0.05150 to 0.04959, saving model to /Users/mostafamousavi/Desktop/EQTransformer/examples/test_trainer_outputs/models/test_trainer_008.h5
# Epoch 9/10
# Learning rate:  0.001
# 6/6 [==============================] - 4s 692ms/step - loss: 0.0549 - detector_loss: 0.4313 - picker_P_loss: 0.0353 - picker_S_loss: 0.0326 - detector_f1: 0.0000e+00 - picker_P_f1: 0.0000e+00 - picker_S_f1: 0.0000e+00 - val_loss: 0.0488 - val_detector_loss: 0.4396 - val_picker_P_loss: 0.0259 - val_picker_S_loss: 0.0276 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00009: val_loss improved from 0.04959 to 0.04883, saving model to /Users/mostafamousavi/Desktop/EQTransformer/examples/test_trainer_outputs/models/test_trainer_009.h5
# Epoch 10/10
# Learning rate:  0.001
# 6/6 [==============================] - 4s 689ms/step - loss: 0.0530 - detector_loss: 0.4162 - picker_P_loss: 0.0336 - picker_S_loss: 0.0317 - detector_f1: 0.0000e+00 - picker_P_f1: 0.0000e+00 - picker_S_f1: 0.0000e+00 - val_loss: 0.0480 - val_detector_loss: 0.4116 - val_picker_P_loss: 0.0274 - val_picker_S_loss: 0.0276 - val_detector_f1: 0.0000e+00 - val_picker_P_f1: 0.0000e+00 - val_picker_S_f1: 0.0000e+00
#
# Epoch 00010: val_loss improved from 0.04883 to 0.04799, saving model to /Users/mostafamousavi/Desktop/EQTransformer/examples/test_trainer_outputs/models/test_trainer_010.h5

# %% [markdown]
# ### 2) Test Your Model:

# %% [markdown]
# You can then test the model you just trained based on the ground truth labels:

# %%
from EQTransformer.core.tester import tester
tester(input_hdf5='../ModelsAndSampleData/100samples.hdf5',
       input_testset='test_trainer_outputs/test.npy',
       input_model='test_trainer_outputs/models/test_trainer_001.h5',
       output_name='test_tester',
       detection_threshold=0.20,                
       P_threshold=0.1,
       S_threshold=0.1, 
       number_of_plots=3,
       estimate_uncertainty=True, 
       number_of_sampling=2,
       input_dimention=(6000, 3),
       normalization_mode='std',
       mode='generator',
       batch_size=10,
       gpuid=None,
       gpu_limit=None)
# Out:
# Loading the model ...
# Loading is complete!
# Testing ...
# Writting results into: " test_tester_outputs "
# 100%|██████████| 2/2 [00:33<00:00, 16.68s/it]
